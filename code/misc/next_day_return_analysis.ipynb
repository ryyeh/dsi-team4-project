# %%
import os
import sys

lib_path = os.path.abspath(os.path.join('..'))
if lib_path not in sys.path:
    sys.path.append(lib_path)

# %%
import pandas as pd
from lib.helper import load_coin_data

# %%
df = load_coin_data()

# %% [markdown]
# # Basic info of the dataset...

# %%
df.head()
# Out:
#      slug symbol    name       date  ranknow      open      high       low  \
# 0  0chain    ZCN  0chain 2018-07-02      441  0.496757  0.530165  0.474749
# 1  0chain    ZCN  0chain 2018-07-03      441  0.480519  0.577536  0.467949
# 2  0chain    ZCN  0chain 2018-07-04      441  0.506340  0.537679  0.470698
# 3  0chain    ZCN  0chain 2018-07-05      441  0.507758  0.620443  0.506720
# 4  0chain    ZCN  0chain 2018-07-06      441  0.619071  0.619081  0.506407
#
#       close    volume      market  close_ratio  spread  next_close  \
# 0  0.479175  296945.0         0.0       0.0799    0.06    0.506107
# 1  0.506107  290003.0  20244280.0       0.3482    0.11    0.505993
# 2  0.505993  384747.0  20239720.0       0.5269    0.07    0.618253
# 3  0.618253  290748.0  24730120.0       0.9807    0.11    0.566018
# 4  0.566018  478795.0  22640720.0       0.5291    0.11    0.616456
#
#    next_return
# 0     0.056205
# 1    -0.000225
# 2     0.221861
# 3    -0.084488
# 4     0.089110

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940223 entries, 0 to 940222
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   slug         940223 non-null  object
#  1   symbol       940223 non-null  object
#  2   name         940223 non-null  object
#  3   date         940223 non-null  datetime64[ns]
#  4   ranknow      940223 non-null  int64
#  5   open         940223 non-null  float64
#  6   high         940223 non-null  float64
#  7   low          940223 non-null  float64
#  8   close        940223 non-null  float64
#  9   volume       940223 non-null  float64
#  10  market       940223 non-null  float64
#  11  close_ratio  940223 non-null  float64
#  12  spread       940223 non-null  float64
#  13  next_close   940223 non-null  float64
#  14  next_return  940223 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(3)
# memory usage: 107.6+ MB

# %% [markdown]
# # Analysis of next day returns

# %%
# for now just deal with one coin and less data
#df = df[df['slug'] == 'bitcoin']

# %%
import matplotlib.pyplot as plt

plt.hist(df['next_return'], log=True)
plt.title('Next day Returns for all coins')
plt.xlabel('Returns')
plt.ylabel('Occurences')
plt.show()

# %% [markdown]
# Observation: there seems to be some outliner of excessive return.

# %%
sorted_by_returns = df.sort_values('next_return')

# %%
sorted_by_returns.head()
# Out:
#               slug symbol          name       date  ranknow       open  \
# 799965        stex   STEX          STEX 2017-06-10     1957    0.27594
# 884517  veritaseum   VERI    Veritaseum 2017-06-10      103   58.58000
# 205435  coimatic-3  CTIC3  Coimatic 3.0 2017-11-08     1728   22.06000
# 155285    breakout    BRK      Breakout 2016-07-08      918  640.69000
# 918508      xaurum   XAUR        Xaurum 2016-08-21      458  617.69000
#
#               high         low       close    volume     market  close_ratio  \
# 799965    0.315555    0.014575    0.228393     405.0        0.0       0.7104
# 884517   84.490000    3.160000    3.160000  379805.0        0.0       0.0000
# 205435   24.310000   21.930000   22.440000      43.0        0.0       0.2143
# 155285  647.120000  640.120000  640.120000   83002.0        0.0       0.0000
# 918508  712.510000  479.900000  697.700000     164.0  5223353.0       0.9363
#
#         spread  next_close  next_return
# ...

# %%
sorted_by_returns.tail()
# Out:
#                          slug  symbol                   name       date  \
# 26864        alphabitcoinfund     ABC               Alphabit 2017-06-11
# 390828  global-cryptocurrency     GCC  Global Cryptocurrency 2017-02-10
# 799966                   stex    STEX                   STEX 2017-06-11
# 25931                 allsafe  ASAFE2                AllSafe 2017-06-22
# 884518             veritaseum    VERI             Veritaseum 2017-06-11
#
#         ranknow      open        high       low     close    volume  market  \
# 26864      2041  0.001272    0.001273  0.001259  0.001273      11.0     0.0
# 390828      917  0.000418    0.000420  0.000010  0.000010    2173.0     0.0
# 799966     1957  0.260675    0.263076  0.000012  0.000013       0.0     0.0
# 25931      1099  0.000009    0.000009  0.000003  0.000003    1994.0  2161.0
# 884518      103  3.350000  112.390000  0.000337  0.000338  311346.0     0.0
#
#         close_ratio  spread  next_close   next_return
# ...
